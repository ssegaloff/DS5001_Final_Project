# %% [markdown]
# F level transformations (raw > tokens > vocab)
# - 01-lib.ipynb
# - 02-corpus.ipynb
# - 03-vocab.ipynb
#
# model derivations
# - 04-dtm-tfidf.ipynb
# - 05-pca.ipynb
# - 06-lda.ipynb
# - 07-sentiment.ipynb
# - 08-word2vec.ipynb
#
# synthesis
# - 09-riffs.ipynb

# %% [markdown]
# still need to add dfidf to vocab table
