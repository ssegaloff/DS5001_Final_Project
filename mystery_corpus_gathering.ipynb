# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="ticks")

# %%
# import text as series of paragraphs
chunk_pat = '\n\n'
chunks = open()
