# %% [markdown]
# F level transformations (raw > tokens > vocab)
# - 01-lib.ipynb
# - 02-corpus.ipynb
# - 03-vocab.ipynb
#
# model derivations
# - 04-dtm-tfidf.ipynb
# - 05-pca.ipynb
# - 06-lda.ipynb
# - 07-sentiment.ipynb
# - 08-word2vec.ipynb
#
# synthesis
# - 09-riffs.ipynb

# %% [markdown]
# ADD HEADERS / EDIT NOTES / POLISH UP
#
# VOCAB - list top 20 significant words by dfidf
#
# PCA - do writeup sections!
