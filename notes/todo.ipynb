# %% [markdown]
# F level transformations (raw > tokens > vocab)
# - 01-lib.ipynb - fix headers
# - 02-corpus.ipynb - fix headers
# - 03-vocab.ipynb - fix headers
#
# model derivations
# - 04-dtm-tfidf.ipynb
#     - get vocab top 20 list by dfidf
# - 05-pca.ipynb
#     - write interpretations!! (for both viz)
#         - discuss how the variance is distributed
#     - top 5 pos terms for pc0 and top 5 neg terms for pc1
#         - need to extract from loadings
#
# - 06-lda.ipynb
#     - PCA + LDA viz (extra credit)
#         - run PCA on THETA.T?
#     - 'friend' - add interpretive note about this as noise in topics
#     - justify n_topics
# - 07-sentiment.ipynb
#     - ?
# - 08-word2vec.ipynb
#     - describe plot
#
# synthesis
# - 09-riffs.ipynb

# %% [markdown]
# ADD HEADERS / EDIT NOTES / POLISH UP
#
# VOCAB - list top 20 significant words by dfidf
#
# PCA - do writeup sections!
#
# improve lda writeups.
#
# export 300 dpi plots
