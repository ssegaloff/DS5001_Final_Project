# %% [markdown]
# Questions
# - How many documents are in the corpus?
# - What is the average length of the documents in the corpus?
# - What are the maximum and minimum lengths of documents in the corpus?
# - What is the OHCO structure of the corpus?
